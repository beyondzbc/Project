# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#配置乐队的夏天主题色
purple = (0.22,0.09,0.59) # 紫色
yellow = (0.99,0.89,0.27) # 黄色
green  = (0.36,0.94,0.55) # 绿色
blue   = (0.06,0.24,0.78) # 蓝色
red    = (0.98,0.31,0.36) # 红色

# %%
data1=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第一场')
data2=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第二场两两PK赛')
data3=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第三场累计积分赛')
data4=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第四场复活赛')
data5=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第五场9进7')
data6=pd.read_excel('D:/pydata/乐队的夏天.xlsx','第六场总决赛')

# %%
data1.head()
# Out:
#     场数  出场顺序     乐队          歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分    总得分   排名  是否晋级下一轮
# 0  第一场    26   海龟先生        男孩别哭    39.0    34.0    88.0  161.0  1.0        1
# 1  第一场    22   痛仰乐队        再见杰克    48.0    30.0    81.0  159.0  2.0        1
# 2  第一场    27    新裤子  别再问我什么是迪斯科    46.0    30.0    83.0  159.0  3.0        1
# 3  第一场     8  旅行团乐队        逝去的歌    41.0    30.0    83.0  154.0  4.0        1
# 4  第一场    15   南无乐队         春来了    37.0    28.0    84.0  149.0  5.0        1

# %%
data1[data1['总得分'].isnull()]
# Out:
#      场数  出场顺序       乐队    歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  总得分  排名  是否晋级下一轮
# 27  第一场    28  MLK麋鹿王国   捉迷藏     NaN     NaN     NaN  NaN NaN        0
# 28  第一场    29      茶凉粉   关于你     NaN     NaN     NaN  NaN NaN        0
# 29  第一场    30       醒山  欢迎光临     NaN     NaN     NaN  NaN NaN        0
# 30  第一场    31    薄荷绿乐队    绵羊     NaN     NaN     NaN  NaN NaN        0

# %%
data1=data1.dropna(axis=0)

# %%
data1
# Out:
#      场数  出场顺序            乐队                     歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  \
# 0   第一场    26          海龟先生                   男孩别哭    39.0    34.0    88.0
# 1   第一场    22          痛仰乐队                   再见杰克    48.0    30.0    81.0
# 2   第一场    27           新裤子             别再问我什么是迪斯科    46.0    30.0    83.0
# 3   第一场     8         旅行团乐队                   逝去的歌    41.0    30.0    83.0
# 4   第一场    15          南无乐队                    春来了    37.0    28.0    84.0
# 5   第一场     1           反光镜                   嘿，姑娘    36.0    28.0    84.0
# 6   第一场    16          九连真人                  莫欺少年穷    38.0    32.0    78.0
# 7   第一场    11          盘尼西林                 雨夜曼彻斯特    44.0    32.0    71.0
# 8   第一场     5          皇后皮箱                  人间惆怅客    37.0    28.0    75.0
# 9   第一场    14          黑撒乐队                   陕西美食    27.0    24.0    80.0
# 10  第一场    25            刺猬          火车驶向云外，梦安魂于九霄    32.0    30.0    68.0
# 11  第一场    13      Click#15              Get Funky    36.0    28.0    65.0
# 12  第一场     7          猴子军团                Fighter    37.0    20.0    71.0
# 13  第一场     9          面孔乐队                      梦    47.0    36.0    43.0
# 14  第一场    23            旺福                  两个恰恰好    33.0    30.0    63.0
# 15  第一场    17          斯斯与帆                  马马嘟嘟骑    36.0    24.0    65.0
# 16  第一场     2         葡萄不愤怒                   迷途未返    28.0    24.0    69.0
# 17  第一场    12           鹿先森                   春风十里    38.0    20.0    60.0
# 18  第一场    18          和平和浪                  丽园便利店    33.0    30.0    41.0
# 19  第一场    21     Mr.WooHoo                     大叔    45.0    30.0    35.0
# 20  第一场     4         熊猫眼乐队                  我爱吃烤鸭    29.0    20.0    60.0
# 21  第一场     6           宇宙人                    你以为    34.0    24.0    50.0
# 22  第一场    19       Mr.Miss                你怎么不上天呢    32.0    38.0    36.0
# 23  第一场    20          果味VC                 噪不完的青春    35.0    26.0    38.0
# 24  第一场    24       VOGUE 5  we shock the game now    28.0    20.0    42.0
# 25  第一场     3         青年小伙子               游戏，我要玩游戏    28.0    22.0    35.0
# 26  第一场    10  BONGBONG邦邦乐团                    要自由    20.0     8.0    29.0
#
#       总得分    排名  是否晋级下一轮
# 0   161.0   1.0        1
# 1   159.0   2.0        1
# 2   159.0   3.0        1
# 3   154.0   4.0        1
# 4   149.0   5.0        1
# 5   148.0   6.0        1
# 6   148.0   7.0        1
# 7   147.0   8.0        1
# 8   140.0   9.0        1
# 9   131.0  10.0        1
# 10  130.0  11.0        1
# 11  129.0  12.0        1
# 12  128.0  13.0        1
# 13  126.0  14.0        1
# 14  126.0  15.0        1
# 15  125.0  16.0        0
# 16  121.0  17.0        0
# 17  118.0  18.0        0
# 18  104.0  19.0        0
# 19  110.0  20.0        1
# 20  109.0  21.0        0
# 21  108.0  22.0        0
# 22  106.0  23.0        0
# 23   99.0  24.0        0
# 24   90.0  25.0        0
# 25   85.0  26.0        0
# 26   57.0  27.0        0

# %%
data6.tail()
# Out:
#       场数  出场顺序        乐队                歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  总得分  投票得分  \
# 7   第六场下     1  Click#15          T.N.L.H.      43      28     279  350    41
# 8   第六场下     2        刺猬              生之向往      36      24     291  351    48
# 9   第六场下     3      盘尼西林  She lost in dark      43      18     246  307    33
# 10  第六场下     4      痛仰乐队              公路之歌      44      28     334  406   133
# 11  第六场下     5       新裤子         没有理想的人不伤心      47      38     338  423   114
#
#     总票数  排名  是否晋级下一轮
# 7   391   4        0
# 8   399   3        0
# 9   340   5        0
# 10  539   2        0
# 11  537   1        0

# %%
fig,ax=plt.subplots(figsize=(12,12))
data1['总得分'].value_counts(bins=5,sort=False).plot.bar(ax=ax)

for tick in ax.get_xticklabels():
    tick.set_rotation(360)
    
ax.grid(False)

# %%
#标准分函数定义
def z_score_normalize(series):
    mean=series.mean()
    std_dv=series.std()
    return series.apply(lambda x:(x-mean)/std_dv)

# %%
#用循环的方式批量对每场比赛的得分做处理
competition=[data1,data2,data3,data4,data5,data6]

for period in competition:
    period['超级乐迷得分_标准分']=z_score_normalize(period['超级乐迷得分'])
    period['专业乐迷得分_标准分']=z_score_normalize(period['专业乐迷得分'])
    period['大众乐迷得分_标准分']=z_score_normalize(period['大众乐迷得分'])
    period['总得分_标准分']=z_score_normalize(period['总得分'])

# %%
data1.sort_values(by='总得分_标准分',ascending=False)
# Out:
#      场数  出场顺序            乐队                     歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  \
# 0   第一场    26          海龟先生                   男孩别哭    39.0    34.0    88.0
# 2   第一场    27           新裤子             别再问我什么是迪斯科    46.0    30.0    83.0
# 1   第一场    22          痛仰乐队                   再见杰克    48.0    30.0    81.0
# 3   第一场     8         旅行团乐队                   逝去的歌    41.0    30.0    83.0
# 4   第一场    15          南无乐队                    春来了    37.0    28.0    84.0
# 5   第一场     1           反光镜                   嘿，姑娘    36.0    28.0    84.0
# 6   第一场    16          九连真人                  莫欺少年穷    38.0    32.0    78.0
# 7   第一场    11          盘尼西林                 雨夜曼彻斯特    44.0    32.0    71.0
# 8   第一场     5          皇后皮箱                  人间惆怅客    37.0    28.0    75.0
# 9   第一场    14          黑撒乐队                   陕西美食    27.0    24.0    80.0
# 10  第一场    25            刺猬          火车驶向云外，梦安魂于九霄    32.0    30.0    68.0
# 11  第一场    13      Click#15              Get Funky    36.0    28.0    65.0
# 12  第一场     7          猴子军团                Fighter    37.0    20.0    71.0
# 14  第一场    23            旺福                  两个恰恰好    33.0    30.0    63.0
# 13  第一场     9          面孔乐队                      梦    47.0    36.0    43.0
# 15  第一场    17          斯斯与帆                  马马嘟嘟骑    36.0    24.0    65.0
# 16  第一场     2         葡萄不愤怒                   迷途未返    28.0    24.0    69.0
# 17  第一场    12           鹿先森                   春风十里    38.0    20.0    60.0
# 19  第一场    21     Mr.WooHoo                     大叔    45.0    30.0    35.0
# 20  第一场     4         熊猫眼乐队                  我爱吃烤鸭    29.0    20.0    60.0
# 21  第一场     6           宇宙人                    你以为    34.0    24.0    50.0
# 22  第一场    19       Mr.Miss                你怎么不上天呢    32.0    38.0    36.0
# 18  第一场    18          和平和浪                  丽园便利店    33.0    30.0    41.0
# 23  第一场    20          果味VC                 噪不完的青春    35.0    26.0    38.0
# 24  第一场    24       VOGUE 5  we shock the game now    28.0    20.0    42.0
# 25  第一场     3         青年小伙子               游戏，我要玩游戏    28.0    22.0    35.0
# 26  第一场    10  BONGBONG邦邦乐团                    要自由    20.0     8.0    29.0
#
#       总得分    排名  是否晋级下一轮  超级乐迷得分_标准分  专业乐迷得分_标准分  大众乐迷得分_标准分   总得分_标准分
# 0   161.0   1.0        1    0.488133    1.154354    1.387279  1.434753
# 2   159.0   3.0        1    1.524731    0.505030    1.119350  1.355695
# 1   159.0   2.0        1    1.820902    0.505030    1.012178  1.355695
# 3   154.0   4.0        1    0.784304    0.505030    1.119350  1.158051
# 4   149.0   5.0        1    0.191963    0.180368    1.172936  0.960406
# 5   148.0   6.0        1    0.043877    0.180368    1.172936  0.920877
# 6   148.0   7.0        1    0.340048    0.829692    0.851420  0.920877
# 7   147.0   8.0        1    1.228560    0.829692    0.476319  0.881348
# 8   140.0   9.0        1    0.191963    0.180368    0.690663  0.604646
# 9   131.0  10.0        1   -1.288891   -0.468956    0.958592  0.248886
# 10  130.0  11.0        1   -0.548464    0.505030    0.315561  0.209357
# 11  129.0  12.0        1    0.043877    0.180368    0.154804  0.169828
# 12  128.0  13.0        1    0.191963   -1.118280    0.476319  0.130299
# 14  126.0  15.0        1   -0.400379    0.505030    0.047632  0.051241
# 13  126.0  14.0        1    1.672816    1.479016   -1.024086  0.051241
# 15  125.0  16.0        0    0.043877   -0.468956    0.154804  0.011712
# 16  121.0  17.0        0   -1.140806   -0.468956    0.369147 -0.146403
# 17  118.0  18.0        0    0.340048   -1.118280   -0.113126 -0.264990
# 19  110.0  20.0        1    1.376645    0.505030   -1.452773 -0.581221
# 20  109.0  21.0        0   -0.992720   -1.118280   -0.113126 -0.620750
# 21  108.0  22.0        0   -0.252294   -0.468956   -0.648985 -0.660279
# 22  106.0  23.0        0   -0.548464    1.803678   -1.399187 -0.739337
# 18  104.0  19.0        0   -0.400379    0.505030   -1.131258 -0.818395
# 23   99.0  24.0        0   -0.104208   -0.144294   -1.292015 -1.016039
# 24   90.0  25.0        0   -1.140806   -1.118280   -1.077672 -1.371800
# 25   85.0  26.0        0   -1.140806   -0.793618   -1.452773 -1.569444
# 26   57.0  27.0        0   -2.325489   -3.066252   -1.774288 -2.676254

# %%
#每场数据是分开的，先截取原来的数据拼在一起成为一个长表
data1_score = data1[['场数','乐队','歌曲','排名','超级乐迷得分_标准分', '专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]
data2_score = data2[['场数','乐队','歌曲','排名','超级乐迷得分_标准分','专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]
data3_score = data3[['场数','乐队','歌曲','排名','超级乐迷得分_标准分','专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]
data4_score = data4[['场数','乐队','歌曲','排名','超级乐迷得分_标准分','专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]
data5_score = data5[['场数','乐队','歌曲','排名','超级乐迷得分_标准分','专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]
data6_score = data6[['场数','乐队','歌曲','排名','超级乐迷得分_标准分','专业乐迷得分_标准分','大众乐迷得分_标准分','总得分_标准分']]

total_score=pd.concat([data1_score,data2_score,data3_score,data4_score,data5_score,data6_score])

# %%
total_score_mean=total_score.groupby(['乐队'])[['总得分_标准分']].mean().sort_values(by='总得分_标准分')

total_score_mean.tail(7).sort_values(by='总得分_标准分',ascending=False)
# Out:
#            总得分_标准分
# 乐队
# 新裤子       1.105277
# 痛仰乐队      0.590946
# 九连真人      0.367531
# 刺猬        0.342829
# 海龟先生      0.251736
# Click#15  0.168296
# 旅行团乐队     0.109426

# %%
#中文显示
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False

#对乐队总得分_标准分做可视化
y=np.arange(len(total_score_mean.index))
x=np.array(list(total_score_mean['总得分_标准分']))
fig,ax=plt.subplots(figsize=(12,12))
total_score_mean.plot.barh(ax=ax,alpha=0.7,title='27只乐队场均表现',color='g')
for a,b in zip(x,y):
    plt.text(a,b,'%.2f' % a,ha='center',va='center',fontsize=12)
ax.grid(False)

# %%
total_score[total_score['乐队']=='痛仰乐队']
#再见杰克和公路之歌我经常单曲循环，传唱度比较高，看来我的审美还是符合主流
# Out:
#       场数    乐队                    歌曲    排名  超级乐迷得分_标准分  专业乐迷得分_标准分  \
# 1    第一场  痛仰乐队                  再见杰克   2.0    1.820902    0.505030
# 7    第二场  痛仰乐队                   我愿意  14.0   -0.121894   -1.105836
# 5    第四场  痛仰乐队                    西湖   1.0    0.688102   -0.380693
# 3    第五场  痛仰乐队  Don't break my heart   4.0    1.186342   -1.340308
# 2   第六场上  痛仰乐队                  奇妙夏日   3.0    0.355955   -1.823676
# 10  第六场下  痛仰乐队                  公路之歌   2.0    0.813612    0.191966
#
#     大众乐迷得分_标准分   总得分_标准分
# 1     1.012178  1.355695
# 7    -1.214141 -1.117903
# 5     1.337629  1.245452
# 3     0.879563  0.645986
# 2     0.397844  0.033497
# 10    1.435698  1.382946

# %%
total_score[total_score['乐队']=='面孔乐队']
#张三的歌我确实觉得不如原唱
# Out:
#         场数    乐队    歌曲    排名  超级乐迷得分_标准分  专业乐迷得分_标准分  大众乐迷得分_标准分   总得分_标准分
# 13     第一场  面孔乐队     梦  14.0    1.672816    1.479016   -1.024086  0.051241
# 6      第二场  面孔乐队    流年  10.0   -0.121894    0.402122   -0.161885 -0.047870
# 16  第二场复活赛  面孔乐队    幻觉   2.0    0.690731   -1.105836   -0.566599 -0.498410
# 1     第三场上  面孔乐队   欢乐颂   3.0   -0.234948    0.490644    0.198886  0.208862
# 12    第三场下  面孔乐队    港湾   6.0    0.619409   -0.672364   -0.306693 -0.271972
# 8      第五场  面孔乐队  张三的歌   9.0   -1.810733   -0.985521   -2.433138 -2.412178

# %%
total_score[total_score['乐队']=='刺猬']
#火车一度单曲循环一整天
# Out:
#         场数  乐队             歌曲    排名  超级乐迷得分_标准分  专业乐迷得分_标准分  大众乐迷得分_标准分  \
# 10     第一场  刺猬  火车驶向云外，梦安魂于九霄  11.0   -0.548464    0.505030    0.315561
# 0      第二场  刺猬           只要平凡   9.0    0.961606    0.402122   -0.323771
# 19  第二场复活赛  刺猬           白日梦蓝   1.0    0.690731    0.402122    0.242828
# 5     第三场上  刺猬    亲爱的，我想做你女朋友   1.0   -0.234948    1.362901    1.120824
# 8     第三场下  刺猬       24小时摇滚聚会   3.0    0.790281   -0.381612    1.358743
# 4      第五场  刺猬           头上的包   5.0    0.062439    0.788417   -0.152967
# 1     第六场上  刺猬         光阴流年夏恋   2.0   -1.627225    0.191966    0.294059
# 8     第六场下  刺猬           生之向往   3.0   -0.406806   -0.383932   -0.051893
#
#      总得分_标准分
# 10  0.209357
# 0   0.064765
# 19  0.402670
# 5   1.098405
# 8   1.146488
# 4   0.041074
# 1  -0.023926
# 8  -0.196197

# %%
total_score[total_score['乐队']=='旅行团乐队']
#周末玩具实在是不好听
# Out:
#       场数     乐队       歌曲   排名  超级乐迷得分_标准分  专业乐迷得分_标准分  大众乐迷得分_标准分   总得分_标准分
# 3    第一场  旅行团乐队     逝去的歌  4.0    0.784304    0.505030    1.119350  1.158051
# 13   第二场  旅行团乐队       氧气  5.0   -0.934519    0.402122    1.699797  1.078480
# 6   第三场上  旅行团乐队     周末玩具  8.0   -1.431049   -1.835373   -2.001869 -2.123181
# 13  第三场下  旅行团乐队  Bye Bye  1.0    1.644638    1.362901    1.477703  1.651363
# 6    第五场  旅行团乐队      鲁冰花  7.0   -1.248781   -0.985521    0.277253 -0.194169
# 6   第六场上  旅行团乐队      夏一站  7.0   -1.627225   -0.959830   -0.501629 -0.913989

# %%
super_score_mean = total_score.groupby(['乐队'])[['超级乐迷得分_标准分']].mean().sort_values(by = '超级乐迷得分_标准分')
pro_score_mean = total_score.groupby(['乐队'])[['专业乐迷得分_标准分']].mean().sort_values(by = '专业乐迷得分_标准分')
public_score_mean = total_score.groupby(['乐队'])[['大众乐迷得分_标准分']].mean().sort_values(by = '大众乐迷得分_标准分')

# %%
fig,ax=plt.subplots(1,3,figsize=(16,6))

super_score_mean.tail(5).plot.barh(ax=ax[0],color = '#dc2624',alpha=0.7,title='超级乐迷心中TOP5',grid=False)
pro_score_mean.tail(5).plot.barh(ax=ax[1],color = '#2b4750',alpha=0.7,title='专业乐迷心中TOP5',grid=False)
public_score_mean.tail(5).plot.barh(ax=ax[2],color = '#649E7D',alpha=0.7,title='大众乐迷心中TOP5',grid=False)

# %%
super_score_mean_top5 = super_score_mean.tail(5)
pro_score_mean_top5 = pro_score_mean.tail(5)
public_score_mean_top5 = public_score_mean.tail(5)

super5=set(super_score_mean_top5.index)
pro5=set(pro_score_mean_top5.index)
pub5=set(public_score_mean_top5.index)

cross = super5&pro5&pub5
print('同时在三个群体中位列心目前五的乐队是:\n',cross)
print('\n')

super_pro = super5 - pro5
print('在超级乐迷心中前五，但不在专业乐迷心中的前五乐队是:\n',super_pro)
print('\n')

super_pub = super5 - pub5
print('在超级乐迷心中前五，但不在大众乐迷心中的前五乐队是:\n',super_pub)
print('\n')

pro_super = pro5 - super5
print('在专业乐迷心中前五，但不在超级乐迷心中的前五乐队是:\n',pro_super)
print('\n')

pro_pub = pro5 - pub5
print('在专业乐迷心中前五，但不在大众乐迷心中的前五乐队是:\n',pro_pub)
print('\n')

pub_super = pub5 - super5
print('在大众乐迷心中前五，但不在超级乐迷心中的前五乐队是:\n',pub_super)
print('\n')

pub_pro = pub5 - pro5
print('在大众乐迷心中前五，但不在专业乐迷心中的前五乐队是:\n',pub_pro)
print('\n')
# Out:
# 同时在三个群体中位列心目前五的乐队是:
#  {'新裤子'}
#
#
# 在超级乐迷心中前五，但不在专业乐迷心中的前五乐队是:
#  {'盘尼西林', '海龟先生', '痛仰乐队'}
#
#
# 在超级乐迷心中前五，但不在大众乐迷心中的前五乐队是:
#  {'盘尼西林', '海龟先生', 'Click#15'}
#
#
# 在专业乐迷心中前五，但不在超级乐迷心中的前五乐队是:
#  {'Mr.Miss', '九连真人', 'Mr.WooHoo'}
#
#
# 在专业乐迷心中前五，但不在大众乐迷心中的前五乐队是:
#  {'Mr.Miss', 'Click#15', 'Mr.WooHoo'}
#
#
# 在大众乐迷心中前五，但不在超级乐迷心中的前五乐队是:
#  {'刺猬', '九连真人', '葡萄不愤怒'}
#
#
# 在大众乐迷心中前五，但不在专业乐迷心中的前五乐队是:
#  {'刺猬', '葡萄不愤怒', '痛仰乐队'}

# %%
print('第五场中表演的九支乐队分别是：')
data5['乐队']
# Out:
# 第五场中表演的九支乐队分别是：
# 0    Click#15
# 1        盘尼西林
# 2         新裤子
# 3        痛仰乐队
# 4          刺猬
# 5        九连真人
# 6       旅行团乐队
# 7        海龟先生
# 8        面孔乐队
# Name: 乐队, dtype: object

# %%
top9_rank = total_score[total_score['乐队'].isin(list(data5['乐队']))].iloc[:,[0,1,3]]

top9_rank = top9_rank.sort_values(by='场数')

fig = plt.figure(figsize=(16,10), dpi=100 )
ax = fig.add_subplot(1,1,1)

order = ['第一场','第二场','第二场复活赛','第三场上','第三场下','第四场','第五场','第六场上']

ax.plot(order,[0,0,0,0,0,0,0,0],c='w')

hgxs = top9_rank[top9_rank['乐队']=='海龟先生'].iloc[[0,3,1,2,4]]
ax.plot('场数','排名',data=hgxs,ls ='--',marker='o',markersize=30,label='海龟先生')

pnxl = top9_rank[top9_rank['乐队']=='盘尼西林'].iloc[[0,3,1,2,4,5]]
ax.plot('场数','排名',data=pnxl,ls ='--',marker='o',markersize=30,label='盘尼西林')

xkz = top9_rank[top9_rank['乐队']=='新裤子'].iloc[[0,3,1,2,4,5]]
ax.plot('场数','排名',data=xkz,ls ='--',marker='o',markersize=30,label='新裤子')

cw = top9_rank[top9_rank['乐队']=='刺猬'].iloc[[0,3,4,1,2,5,6]]
ax.plot('场数','排名',data=cw,ls ='--',marker='o',markersize=30,label='刺猬')

ty = top9_rank[top9_rank['乐队']=='痛仰乐队'].iloc[[0,1,5,3,2,4]]
ax.plot('场数','排名',data=ty,ls ='--',marker='o',markersize=30,label='痛仰乐队')

click = top9_rank[top9_rank['乐队']=='Click#15'].iloc[[0,1,2,6,3,4,5]]
ax.plot('场数','排名',data=click,ls ='--',marker='o',markersize=30,label='Click#15')

jlzr = top9_rank[top9_rank['乐队']=='九连真人'].iloc[[0,3,1,2,4,5]]
ax.plot('场数','排名',data=jlzr,ls ='--',marker='o',markersize=30,label='九连真人')

mk = top9_rank[top9_rank['乐队']=='面孔乐队'].iloc[[0,3,4,1,2,5]]
ax.plot('场数','排名',data=mk,ls ='--',marker='o',markersize=30,label='面孔乐队')

lxt = top9_rank[top9_rank['乐队']=='旅行团乐队'].iloc[[0,3,1,2,4,5]]
ax.plot('场数','排名',data=lxt,ls ='--',marker='o',markersize=30,label='旅行团乐队')

ax.set_xticks(np.arange(len(order)))
ax.set_yticks(np.arange(1,15))
ax.set_xticklabels(order)
ax.invert_yaxis()
ax.set_ylim(15,0)
ax.grid(False)
plt.title('九只队伍排名升降',fontdict = {'fontsize':20})
ax.legend(ncol=3)

# %% [markdown]
#  歌曲分析

# %%
#得票率=得票数/总票数，然后变成一个0-1之间的数字

# %%
#定义归一化函数并应用
def normalize(series,x_max):
    return series.apply(lambda x: x/x_max)

# %%
for data in [data1,data2,data5,data6]:
    data['超级乐迷_归一分'] = normalize(data['超级乐迷得分'],50)

data3['超级乐迷_归一分'] = normalize(data3['超级乐迷得分'],60)
data4['超级乐迷_归一分'] = normalize(data4['超级乐迷得分'],40)

for data in [data1,data2,data3,data4,data5,data6]:
    data['专业乐迷_归一分'] = normalize(data['专业乐迷得分'],40)
    
for data in [data1,data2]:
    data['大众乐迷_归一分'] = normalize(data['大众乐迷得分'],100)
for data in [data3,data4,data5,data6]:
    data['大众乐迷_归一分'] = normalize(data['大众乐迷得分'],360)

# %%
data6
# Out:
#       场数  出场顺序        乐队                        歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  \
# 0   第六场上     7       新裤子                      夏日终曲      42      34     319
# 1   第六场上     5        刺猬                    光阴流年夏恋      28      28     301
# 2   第六场上     2      痛仰乐队                      奇妙夏日      41      14     304
# 3   第六场上     1  Click#15  B FUNK FOR Summer Troops      41      34     278
# 4   第六场上     3      盘尼西林           The Summer Star      41      26     251
# 5   第六场上     4      九连真人                        一浪      30      28     291
# 6   第六场上     6     旅行团乐队                       夏一站      28      20     278
# 7   第六场下     1  Click#15                  T.N.L.H.      43      28     279
# 8   第六场下     2        刺猬                      生之向往      36      24     291
# 9   第六场下     3      盘尼西林          She lost in dark      43      18     246
# 10  第六场下     4      痛仰乐队                      公路之歌      44      28     334
# 11  第六场下     5       新裤子                 没有理想的人不伤心      47      38     338
#
#     总得分  投票得分  总票数  排名  是否晋级下一轮  超级乐迷得分_标准分  专业乐迷得分_标准分  大众乐迷得分_标准分   总得分_标准分  \
# 0   395    37  432   1        1    0.508508    1.055813    0.916771  1.067118
# 1   357    66  423   2        1   -1.627225    0.191966    0.294059 -0.023926
# 2   359    43  402   3        1    0.355955   -1.823676    0.397844  0.033497
# 3   353    48  401   4        1    0.355955    1.055813   -0.501629 -0.138773
# 4   318    74  392   5        1    0.355955   -0.095983   -1.435698 -1.143682
# 5   349    41  390   6        0   -1.322120    0.191966   -0.051893 -0.253620
# 6   326    62  388   7        0   -1.627225   -0.959830   -0.501629 -0.913989
# 7   350    41  391   4        0    0.661060    0.191966   -0.467034 -0.224908
# 8   351    48  399   3        0   -0.406806   -0.383932   -0.051893 -0.196197
# 9   307    33  340   5        0    0.661060   -1.247779   -1.608674 -1.459511
# 10  406   133  539   2        0    0.813612    0.191966    1.435698  1.382946
# 11  423   114  537   1        0    1.271269    1.631710    1.574078  1.871045
#
#     超级乐迷_归一分  专业乐迷_归一分  大众乐迷_归一分
# 0       0.84      0.85  0.886111
# 1       0.56      0.70  0.836111
# 2       0.82      0.35  0.844444
# 3       0.82      0.85  0.772222
# 4       0.82      0.65  0.697222
# 5       0.60      0.70  0.808333
# 6       0.56      0.50  0.772222
# 7       0.86      0.70  0.775000
# 8       0.72      0.60  0.808333
# 9       0.86      0.45  0.683333
# 10      0.88      0.70  0.927778
# 11      0.94      0.95  0.938889

# %%
#批量对总得分应用归一化函数
match_total = {'data1':190,'data2':190,'data3':460,'data4':440,'data5':450,'data6':450}
data_list = [data1,data2,data3,data4,data5,data6]

for i,data in enumerate(data_list):
    data['总得分_归一分'] = normalize(data['总得分'],match_total['data'+ str(i+1)])

# %%
col_index = [3,-4,-3,-2,-1]
total_nor_score = pd.DataFrame()
for data in data_list:
    total_nor_score = total_nor_score.append([data.iloc[:,col_index]])

# %%
total_nor_score.sort_values(by = '总得分_归一分',ascending=False)
# Out:
#                                歌曲  超级乐迷_归一分  专业乐迷_归一分  大众乐迷_归一分   总得分_归一分
# 11                      没有理想的人不伤心  0.940000      0.95  0.938889  0.940000
# 10                           公路之歌  0.880000      0.70  0.927778  0.902222
# 13                        Bye Bye  0.950000      0.95  0.883333  0.897826
# 14                             花火  0.860000      0.90  0.900000  0.889474
# 5                              西湖  0.900000      0.50  0.925000  0.884091
# 0                            椑面派对  0.940000      0.90  0.872222  0.882222
# 10                        生命因你而火热  0.900000      0.80  0.886111  0.880435
# 4   How come u leave me like this  0.975000      0.70  0.888889  0.879545
# 3                             凡人歌  0.880000      0.85  0.890000  0.878947
# 0                            夏日终曲  0.840000      0.85  0.886111  0.877778
# 1                             红河谷  0.920000      0.80  0.880556  0.877778
# 3            Don't break my heart  0.980000      0.50  0.897222  0.871111
# 2                         一场游戏一场梦  0.880000      0.75  0.883333  0.871111
# 5                              日光  0.880000      0.90  0.820000  0.852632
# 8                        24小时摇滚聚会  0.866667      0.65  0.872222  0.852174
# 5                     亲爱的，我想做你女朋友  0.766667      0.95  0.850000  0.847826
# 0                            男孩别哭  0.780000      0.85  0.880000  0.847368
# 1                            再见杰克  0.960000      0.75  0.810000  0.836842
# 2                      别再问我什么是迪斯科  0.920000      0.75  0.830000  0.836842
# 8                             甜蜜蜜  0.860000      0.85  0.820000  0.836842
# 4                            头上的包  0.860000      0.80  0.830556  0.831111
# 5                             落水天  0.800000      0.75  0.841667  0.828889
# 13                             氧气  0.720000      0.80  0.890000  0.826316
# 6                             鲁冰花  0.720000      0.55  0.858333  0.815556
# 3                            逝去的歌  0.820000      0.75  0.830000  0.810526
# 7                         蓝精灵+忘记他  0.920000      0.60  0.816667  0.808889
# 2                            奇妙夏日  0.820000      0.35  0.844444  0.797778
# 0                            再谈回忆  0.750000      0.70  0.813889  0.795652
# 1                          光阴流年夏恋  0.560000      0.70  0.836111  0.793333
# 3        B FUNK FOR Summer Troops  0.820000      0.85  0.772222  0.784444
# ..                            ...       ...       ...       ...       ...
# 15                        Someday  0.766667      0.70  0.655556  0.673913
# 12                        Fighter  0.740000      0.50  0.710000  0.673684
# 8                            张三的歌  0.660000      0.55  0.683333  0.668889
# 14                          两个恰恰好  0.660000      0.75  0.630000  0.663158
# 13                              梦  0.940000      0.90  0.430000  0.663158
# 15                          马马嘟嘟骑  0.720000      0.60  0.650000  0.657895
# 7                             咿呀呀  0.683333      0.40  0.677778  0.654348
# 12                        Darling  0.680000      0.75  0.600000  0.652632
# 15                          怒放的生命  0.740000      0.70  0.580000  0.647368
# 17         Steal Your Love For Me  0.860000      0.55  0.580000  0.647368
# 1                              天下  0.680000      0.70  0.610000  0.647368
# 16                           迷途未返  0.560000      0.60  0.690000  0.636842
# 18                        如果这些都可以  0.740000      0.60  0.600000  0.636842
# 17                           春风十里  0.760000      0.50  0.600000  0.621053
# 11                           生如夏花  0.680000      0.70  0.560000  0.621053
# 7                             我愿意  0.780000      0.65  0.530000  0.621053
# 4                         无与伦比的美丽  0.680000      0.70  0.510000  0.594737
# 19                             大叔  0.900000      0.75  0.350000  0.578947
# 20                          我爱吃烤鸭  0.580000      0.50  0.600000  0.573684
# 2                            一万小时  0.725000      0.45  0.566667  0.570455
# 21                            你以为  0.680000      0.60  0.500000  0.568421
# 0                              日落  0.650000      0.50  0.558333  0.561364
# 22                        你怎么不上天呢  0.640000      0.95  0.360000  0.557895
# 6                            周末玩具  0.650000      0.40  0.558333  0.556522
# 18                          丽园便利店  0.660000      0.75  0.410000  0.547368
# 3                           动机zoo  0.775000      0.50  0.522222  0.543182
# 23                         噪不完的青春  0.700000      0.65  0.380000  0.521053
# 24          we shock the game now  0.560000      0.50  0.420000  0.473684
# 25                       游戏，我要玩游戏  0.560000      0.55  0.350000  0.447368
# 26                            要自由  0.400000      0.20  0.290000  0.300000
#
# [90 rows x 5 columns]

# %%
total_nor_score.describe()
# Out:
#         超级乐迷_归一分   专业乐迷_归一分   大众乐迷_归一分    总得分_归一分
# count  90.000000  90.000000  90.000000  90.000000
# mean    0.772815   0.691111   0.708247   0.725818
# std     0.118366   0.151690   0.154311   0.119774
# min     0.400000   0.200000   0.290000   0.300000
# 25%     0.687500   0.600000   0.610000   0.653061
# 50%     0.770833   0.700000   0.711944   0.731007
# 75%     0.860000   0.800000   0.834722   0.823626
# max     0.980000   0.950000   0.938889   0.940000

# %%
fig,ax = plt.subplots(1,1,figsize = (8,4))
total_nor_score.boxplot(ax = ax,grid=False)
ax.set(title = '各组评委打分分布')
# Out:
# [Text(0.5, 1.0, '各组评委打分分布')]

# %%
top10_songs = total_nor_score.sort_values(by = '总得分_归一分').tail(10)
top10_songs.plot.barh(x='歌曲',y='总得分_归一分',color=purple)

print('截止第六期，最受欢迎的10首歌分别是:\n',list(top10_songs['歌曲']))
# Out:
# 截止第六期，最受欢迎的10首歌分别是:
#  ['夏日终曲', '凡人歌', 'How come u leave me like this', '生命因你而火热', '椑面派对', '西湖', '花火', 'Bye Bye', '公路之歌', '没有理想的人不伤心']

# %%
total_nor_score.sort_values(by = '超级乐迷_归一分').tail(10).plot.barh(x='歌曲',y='超级乐迷_归一分',color=red)

# %%
total_nor_score.sort_values(by = '专业乐迷_归一分').tail(10).plot.barh(x='歌曲',y='专业乐迷_归一分',color=yellow)

# %%
total_nor_score.sort_values(by = '大众乐迷_归一分').tail(10).plot.barh(x='歌曲',y='大众乐迷_归一分',color=green)

# %%
total_nor_score[total_nor_score['歌曲'] == '我愿意']
# Out:
#     歌曲  超级乐迷_归一分  专业乐迷_归一分  大众乐迷_归一分   总得分_归一分
# 7  我愿意      0.78      0.65      0.53  0.621053

# %%
total_nor_score_t = pd.merge(total_nor_score, total_score[['乐队','歌曲']], on='歌曲')
total_nor_score_t[total_nor_score_t['乐队'] == '海龟先生']
# Out:
#                      歌曲  超级乐迷_归一分  专业乐迷_归一分  大众乐迷_归一分   总得分_归一分    乐队
# 0                  男孩别哭  0.780000      0.85  0.880000  0.847368  海龟先生
# 32                   日光  0.880000      0.90  0.820000  0.852632  海龟先生
# 54                  咿呀呀  0.683333      0.40  0.677778  0.654348  海龟先生
# 61  Where are you going  0.916667      0.70  0.702778  0.730435  海龟先生
# 76              蓝精灵+忘记他  0.920000      0.60  0.816667  0.808889  海龟先生

# %%
total_nor_score_t[total_nor_score_t['乐队'] == '海龟先生'].mean()
# Out:
# 超级乐迷_归一分    0.836000
# 专业乐迷_归一分    0.690000
# 大众乐迷_归一分    0.779444
# 总得分_归一分     0.778734
# dtype: float64

# %%
total_nor_score_t.iloc[[0,32,61,76]].mean()
# Out:
# 超级乐迷_归一分    0.874167
# 专业乐迷_归一分    0.762500
# 大众乐迷_归一分    0.804861
# 总得分_归一分     0.809831
# dtype: float64

# %%
total_nor_score_t.groupby('乐队').mean().sort_values(by = '总得分_归一分',ascending = False).head(9)
# Out:
#           超级乐迷_归一分  专业乐迷_归一分  大众乐迷_归一分   总得分_归一分
# 乐队
# 新裤子       0.867619  0.821429  0.861032  0.858073
# 痛仰乐队      0.886667  0.575000  0.822407  0.818849
# 九连真人      0.762222  0.800000  0.795926  0.791549
# 刺猬        0.764167  0.756250  0.778403  0.785424
# 海龟先生      0.836000  0.690000  0.779444  0.778734
# 旅行团乐队     0.736667  0.658333  0.798704  0.771865
# Click#15  0.856429  0.750000  0.742619  0.770344
# 盘尼西林      0.850476  0.671429  0.737381  0.754228
# 南无乐队      0.710000  0.700000  0.725000  0.715789

# %%
total_score_mean.sort_values(by = '总得分_标准分',ascending= False).head(9)
# Out:
#            总得分_标准分
# 乐队
# 新裤子       1.105277
# 痛仰乐队      0.590946
# 九连真人      0.367531
# 刺猬        0.342829
# 海龟先生      0.251736
# Click#15  0.168296
# 旅行团乐队     0.109426
# 南无乐队      0.062046
# 反光镜       0.042281

# %%
# 这里面有些中途甚至很早就被淘汰了的乐队，如果把这些乐队排除，那么在最终的7只乐队里面，各组评委最喜欢谁呢？
import warnings
warnings.filterwarnings('ignore')
final_7 = ['新裤子','痛仰乐队','九连真人','Click#15','刺猬','盘尼西林','旅行团乐队']
final_7_super_score = super_score_mean.loc[final_7,].sort_values(by='超级乐迷得分_标准分')
final_7_pro_score = pro_score_mean.loc[final_7,].sort_values(by='专业乐迷得分_标准分')
final_7_public_score = public_score_mean.loc[final_7,].sort_values(by='大众乐迷得分_标准分')
final_7_total_score = total_score_mean.loc[final_7,].sort_values(by='总得分_标准分')

fig,ax = plt.subplots(4,1,figsize = (10,20))

final_7_total_score.plot.barh(ax=ax[0],color = yellow,alpha=0.7,title='普通乐迷心中Hot5',grid=False)
final_7_super_score.plot.barh(ax=ax[1],color = '#dc2624',alpha=0.7,title='超级乐迷心中Hot5',grid=False)
final_7_pro_score.plot.barh(ax=ax[2],color = '#2b4750',alpha=0.7,title='专业乐迷心中Hot5',grid=False)
final_7_public_score.plot.barh(ax=ax[3],color = '#649E7D',alpha=0.7,title='大众乐迷心中Hot5',grid=False)

# %%
data6.iloc[:,:-9]
# Out:
#       场数  出场顺序        乐队                        歌曲  超级乐迷得分  专业乐迷得分  大众乐迷得分  \
# 0   第六场上     7       新裤子                      夏日终曲      42      34     319
# 1   第六场上     5        刺猬                    光阴流年夏恋      28      28     301
# 2   第六场上     2      痛仰乐队                      奇妙夏日      41      14     304
# 3   第六场上     1  Click#15  B FUNK FOR Summer Troops      41      34     278
# 4   第六场上     3      盘尼西林           The Summer Star      41      26     251
# 5   第六场上     4      九连真人                        一浪      30      28     291
# 6   第六场上     6     旅行团乐队                       夏一站      28      20     278
# 7   第六场下     1  Click#15                  T.N.L.H.      43      28     279
# 8   第六场下     2        刺猬                      生之向往      36      24     291
# 9   第六场下     3      盘尼西林          She lost in dark      43      18     246
# 10  第六场下     4      痛仰乐队                      公路之歌      44      28     334
# 11  第六场下     5       新裤子                 没有理想的人不伤心      47      38     338
#
#     总得分  投票得分  总票数  排名
# 0   395    37  432   1
# 1   357    66  423   2
# 2   359    43  402   3
# 3   353    48  401   4
# 4   318    74  392   5
# 5   349    41  390   6
# 6   326    62  388   7
# 7   350    41  391   4
# 8   351    48  399   3
# 9   307    33  340   5
# 10  406   133  539   2
# 11  423   114  537   1
